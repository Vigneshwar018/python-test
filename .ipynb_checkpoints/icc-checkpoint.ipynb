# %%
import numpy as np 
import pandas as pd 
import datetime

fl = pd.read_csv('icc/india-player.csv')

# %%
fl.head()
# Out:
#                      Name Date of birth   Team   Batting Style  \
# 0   Aashish Rakesh Kapoor    25-03-1971  INDIA  Right-hand bat
# 1  Aavishkar Madhav Salvi    20-10-1981  INDIA  Right-hand bat
# 2          Abey Kuruvilla    04-08-1968  INDIA  Right-hand bat
# 3     Abhijit Vasant Kale    03-07-1973  INDIA  Right-hand bat
# 4        Abhimanyu Mithun    25-10-1989  INDIA  Right-hand bat
#
#            Bowling Style         ODI Debut            Debut Team  \
# 0              Off-break  February 22,1995     Australia v India
# 1       Right-arm medium     April 11,2003    Bangladesh v India
# 2  Right-arm fast-medium     April 26,1997   West Indies v India
# 3              Off-break     April 16,2003    Bangladesh v India
# 4       Right-arm medium  February 27,2010  India v South Africa
#
#    Matches played  Innings  Total Run  Not Out Highe Score Batting Avg  \
# 0              17        6         43        0          19       7.166
# 1               4        3          4        1          4*       2.000
# 2              25       11         26        4           7       3.714
# 3               1        1         10        0          10       10.00
# 4               5        3         51        0          24       17.00
#
#    Balls faced Stick rate  100s  50s 4s 6s Caught Stumped Balls Runs Wickets  \
# 0           63      68.25     0    0  2  1      1       0   900  612       8
# 1           14      28.57     0    0  0  0      2       0   172  120       4
# 2           43      60.46     0    0  1  1      4       0  1131  890      25
# 3           22      45.45     0    0  1  0     --      --    --   --      --
# 4           55      92.72     0    0  2  4      1       0   180  203       3
#
#   Bowling Avg Economy Stick rate.1 5WI 10WM   BBI   BBM
# 0       76.50   4.080        112.5   0    0  2/19  2/29
# 1       30.00   4.186        43.00   0    0  2/15  2/15
# 2       35.60   4.721        45.24   0    0  4/43  4/43
# 3          --      --           --  --   --   NaN   NaN
# 4       67.66   6.766        60.00   0    0  2/25  2/25

# %%
#fl['ODI Debut'] = pd.to_datetime(fl['ODI Debut']) 

 
fl['Date of birth'] = pd.to_datetime(fl['Date of birth'])

# %%
deb = fl['Debut Team'].apply(lambda x: x.split(' v'))

# %%
fl['Team'] = fl['Team'].str.capitalize()

def te(x):
    if x[0] == fl['Team'].all():
        return x[1]
    else:
        return x[0]
        
fl['Debut Team'] = deb.apply(te)

# %%
pd.set_option('display.max_columns', 31)
fl
# Out:
#                                Name Date of birth   Team   Batting Style  \
# 0             Aashish Rakesh Kapoor    1971-03-25  India  Right-hand bat
# 1            Aavishkar Madhav Salvi    1981-10-20  India  Right-hand bat
# 2                    Abey Kuruvilla    1968-04-08  India  Right-hand bat
# 3               Abhijit Vasant Kale    1973-03-07  India  Right-hand bat
# 4                  Abhimanyu Mithun    1989-10-25  India  Right-hand bat
# ..                              ...           ...    ...             ...
# 199                  Yashpal Sharma    1954-11-08  India  Right-hand bat
# 200  Yograj Singh Bhagsingh Bhundel    1958-03-25  India  Right-hand bat
# 201               Yusuf Khan Pathan    1984-11-27  India  Right-hand bat
# 202                    Yuvraj Singh    1981-12-12  India   Left-hand bat
# 203                     Zaheer Khan    1978-07-10  India  Right-hand bat
#
#                       Bowling Style         ODI Debut     Debut Team  \
# 0                         Off-break  February 22,1995      Australia
# 1                  Right-arm medium     April 11,2003     Bangladesh
# 2             Right-arm fast-medium     April 26,1997    West Indies
# 3                         Off-break     April 16,2003     Bangladesh
# 4                  Right-arm medium  February 27,2010   South Africa
# ..                              ...               ...            ...
# 199                Right-arm medium   October 13,1978       Pakistan
# 200           Right-arm fast-medium  December 21,1980    New Zealand
# 201                       Off-break      June 10,2008       Pakistan
# 202  Slow left-arm, Left-arm medium    October 3,2000          Kenya
# 203            Left-arm fast-medium    October 3,2000          Kenya
#
#      Matches played  Innings  Total Run  Not Out Highe Score Batting Avg  \
# 0                17        6         43        0          19       7.166
# 1                 4        3          4        1           4       2.000
# 2                25       11         26        4           7       3.714
# 3                 1        1         10        0          10       10.00
# 4                 5        3         51        0          24       17.00
# ..              ...      ...        ...      ...         ...         ...
# 199              42       40        883        9          89       28.48
# 200               6        4          1        2           1       0.500
# 201              57       41        810       11         123       27.00
# 202             304      278       8701       40         150       36.55
# 203             200      101        792       35          34       12.00
#
#      Balls faced Stick rate  100s  50s   4s   6s Caught Stumped  Balls  Runs  \
# 0             63      68.25     0    0    2    1      1       0    900   612
# 1             14      28.57     0    0    0    0      2       0    172   120
# 2             43      60.46     0    0    1    1      4       0   1131   890
# 3             22      45.45     0    0    1    0      0       0      0     0
# 4             55      92.72     0    0    2    4      1       0    180   203
# ..           ...        ...   ...  ...  ...  ...    ...     ...    ...   ...
# 199         1360      64.92     0    4   44    2     10       0    201   199
# 200           12      8.333     0    0    0    0      2       0    244   186
# 201          713      113.6     2    3   62   43     17       0   1490  1365
# 202         9925      87.66    14   52  908  155     94       0   5048  4294
# 203         1078      73.46     0    0   69   24     43       0  10097  8301
#
#     Wickets Bowling Avg Economy Stick rate.1 5WI 10WM   BBI   BBM
# 0         8       76.50   4.080        112.5   0    0  2/19  2/29
# 1         4       30.00   4.186        43.00   0    0  2/15  2/15
# 2        25       35.60   4.721        45.24   0    0  4/43  4/43
# 3         0           0       0            0   0    0     0     0
# 4         3       67.66   6.766        60.00   0    0  2/25  2/25
# ..      ...         ...     ...          ...  ..  ...   ...   ...
# 199       1       199.0   5.940        201.0   0    0   1/6   1/6
# 200       4       46.50   4.573        61.00   0    0  2/44  2/44
# 201      33       41.36   5.496        45.15   0    0  3/20  3/20
# 202     111       38.68   5.103        45.47   1    0  5/31  5/31
# 203     282       29.43   4.932        35.80   1    0  5/29  5/42
#
# [204 rows x 31 columns]

# %%
fl['Highe Score'] = fl['Highe Score'].str.replace('*','')

# %%
def rep(x, a, b):
    return x.replace(a,b)

fl = fl.apply(rep, args=('--','0'))
fl = fl.apply(rep, args=('NaN','0'))

# %%
fl.fillna(value=0, inplace=True)

# %%
fl.iloc[:,2]
# Out:
# 0      India
# 1      India
# 2      India
# 3      India
# 4      India
#        ...
# 199    India
# 200    India
# 201    India
# 202    India
# 203    India
# Name: Team, Length: 204, dtype: object
