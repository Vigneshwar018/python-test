# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
fl = pd.read_csv('all_odi_players.csv', parse_dates = ['Date of birth', 'ODI Debut'] )

# %%
pd.set_option('display.max_columns', 31)
fl
# Out:
#                       Name Date of birth         Team   Batting Style  \
# 0      Aaron James Redmond    1979-09-23  new zealand  Right-hand bat
# 1        Adam Fraser Milne    1992-04-13  new zealand  Right-hand bat
# 2        Adam Craig Parore    1971-01-23  new zealand  Right-hand bat
# 3           Alex Ross Tait    1972-06-13  new zealand  Right-hand bat
# 4         Andre Ryan Adams    1975-07-17  new zealand  Right-hand bat
# ...                    ...           ...          ...             ...
# 1962    Victor James Marks    1955-06-25      england  Right-hand bat
# 1963  Vikram Singh Solanki    1976-01-04      england  Right-hand bat
# 1964    Vincent John Wells    1965-06-08      england  Right-hand bat
# 1965         Wayne Larkins    1953-11-22      england  Right-hand bat
# 1966  Wilfred Norris Slack    1954-12-12      england   Left-hand bat
#
#               Bowling Style  ODI Debut    Debut Team  Matches played  Innings  \
# ...

# %%
# %matplotlib inline
fl.groupby('Team').sum().plot()

# %%
fl['Total Run'].mean()
# Out:
# 760.8159633960346
