# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
fl1 = pd.read_csv('passwords.csv')

revF = fl1.loc[:,'name'].apply(lambda x: x[::-1])

revF = revF.apply(lambda x: x.split('.')[1])

revF = revF.apply(lambda x: x[::-1])

fl1['site'] = revF

fl1 = fl1.reindex(columns=[ 'site', 'username', 'password', 'url', 'name'])

fl1.to_csv('out_pass.csv', index=False)

# %%
out = pd.read_csv('out_pass.csv')

res = out.groupby('site').count()

pd.set_option('display.max_rows', 70)

res
# Out:
#                 username  password  url  name
# site
# 000webhost             9        10   10    10
# 000webhostapp          2         2    2     2
# 43                     1         1    1     1
# acttv                  1         1    1     1
# airtel                 1         1    1     1
# amazon                 5         6    6     6
# avast                  0         1    1     1
# boxopus                1         2    2     2
# cbox                   0         1    1     1
# co                     1         1    1     1
# codeanywhere           0         1    1     1
# codebabes              1         1    1     1
# codepen                1         1    1     1
# ctfile                 1         1    1     1
# dailyleech             1         1    1     1
# dropbox                1         1    1     1
# envato                 0         1    1     1
# facebook               4         4    4     4
# filestream             2         3    3     3
# firstnaukri            1         1    1     1
# flipkart               1         1    1     1
# freenom                2         2    2     2
# furk                   1         1    1     1
# github                 2         2    2     2
# godaddy                1         1    1     1
# google                16        16   16    16
# gov                    3         3    3     3
# hdfcbank               1         1    1     1
# icicibank              2         2    2     2
# ixigo                  1         0    1     1
# jsfiddle               1         1    1     1
# kat                    2         2    2     2
# learnyst               1         1    1     1
# live                   3         3    3     3
# myntra                 2         0    2     2
# naukri                 0         1    1     1
# net2ftp                3         3    3     3
# nlcindia               1         1    1     1
# nobroker               1         1    1     1
# olx                    1         1    1     1
# online-convert         1         1    1     1
# paytm                  1         3    3     3
# pinterest              1         1    1     1
# quikr                  1         1    1     1
# rapidgator             1         1    1     1
# rediffmail             1         1    1     1
# seedr                  2         2    2     2
# skillshare             3         3    3     3
# snapdeal               2         2    2     2
# spike2k14              1         1    1     1
# tamilnow               2         2    2     2
# tamilrockers           1         1    1     1
# techmahindra           6         6    6     6
# tnagarlks              1         1    1     1
# tnebnet                4         4    4     4
# tnpsc                  1         1    1     1
# tnpsconline            2         2    2     2
# tunnelbear             0         1    1     1
# twinstrangers          1         1    1     1
# twitter                6         6    6     6
# uber                   0         1    1     1
# udemy                  1         1    1     1
# vmall                  1         1    1     1
# vpnflat                1         1    1     1
# xiaomi                 1         2    2     2
# yahoo                  1         1    1     1
# zbigz                  2         2    2     2
