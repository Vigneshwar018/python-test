# %%
import numpy as np 
import pandas as pd 
import datetime

fl = pd.read_csv('icc/all_player.csv')

# %%
fl['Date of birth'] = pd.to_datetime(fl['Date of birth'])
fl
# Out:
#                       Name Date of birth         Team   Batting Style  \
# 0      Aaron James Redmond    1979-09-23  NEW ZEALAND  Right-hand bat
# 1        Adam Fraser Milne    1992-04-13  NEW ZEALAND  Right-hand bat
# 2        Adam Craig Parore    1971-01-23  NEW ZEALAND  Right-hand bat
# 3           Alex Ross Tait    1972-06-13  NEW ZEALAND  Right-hand bat
# 4         Andre Ryan Adams    1975-07-17  NEW ZEALAND  Right-hand bat
# ...                    ...           ...          ...             ...
# 3929    Victor James Marks    1955-06-25      ENGLAND  Right-hand bat
# 3930  Vikram Singh Solanki    1976-01-04      ENGLAND  Right-hand bat
# 3931    Vincent John Wells    1965-06-08      ENGLAND  Right-hand bat
# 3932         Wayne Larkins    1953-11-22      ENGLAND  Right-hand bat
# 3933  Wilfred Norris Slack    1954-12-12      ENGLAND   Left-hand bat
#
#               Bowling Style         ODI Debut               Debut Team  \
# 0                 Leg-break    October 3,2009   New Zealand v Pakistan
# 1            Right-arm fast  November 10,2012  Sri Lanka v New Zealand
# 2                       NaN   October 31,1992   Zimbabwe v New Zealand
# 3          Right-arm medium   October 24,1998   New Zealand v Zimbabwe
# 4     Right-arm fast-medium     April 10,2001  New Zealand v Sri Lanka
# ...                     ...               ...                      ...
# 3929              Off-break       May 30,1980    England v West Indies
# 3930              Off-break   January 23,2000   South Africa v England
# 3931       Right-arm medium   January 10,1999      Australia v England
# 3932       Right-arm medium      June 20,1979    England v New Zealand
# 3933       Right-arm medium      March 4,1986    West Indies v England
#
#       Matches played  Innings  Total Run  ...  Balls  Runs Wickets  \
# 0                  6        6        152  ...     --    --      --
# 1                 40       17        168  ...   1801  1581      41
# 2                179      161       3314  ...     --    --      --
# 3                  5        5         35  ...    120    88       3
# 4                 42       34        419  ...   1885  1643      53
# ...              ...      ...        ...  ...    ...   ...     ...
# 3929              34       24        285  ...   1838  1135      44
# 3930              51       46       1097  ...    111   105       1
# 3931               9        7        141  ...    220   189       8
# 3932              25       24        591  ...     15    22       0
# 3933               2        2         43  ...     --    --      --
#
#       Bowling Avg Economy  Stick rate.1  5WI 10WM   BBI   BBM
# 0              --      --            --   --   --   NaN   NaN
# 1           38.56   5.267         43.92    0    0   1/8   1/8
# 2              --      --            --   --   --   NaN   NaN
# 3           29.33   4.400         40.00    0    0  2/37  2/37
# 4           31.00   5.229         35.56    1    0  5/22  5/22
# ...           ...     ...           ...  ...  ...   ...   ...
# 3929        25.79   3.705         41.77    2    0  5/20  5/20
# 3930        105.0   5.675         111.0    0    0  1/17  1/17
# 3931        23.62   5.154         27.50    0    0  3/30  3/30
# 3932           --   8.800            --    0    0   0/1   0/1
# 3933           --      --            --   --   --   NaN   NaN
#
# [3934 rows x 31 columns]

# %%
fl['Debut Team'] = fl['Debut Team'].str.lower()
deb = fl['Debut Team'].apply(lambda x: x.split(' v'))

# %%
fl['Team'] = fl['Team'].str.lower()

def te(x):
    if x[0] == fl['Team'].all():
        return x[1]
    else:
        return x[0]
        
fl['Debut Team'] = deb.apply(te)

# %%
pd.set_option('display.max_columns', 31)

# %%
fl['Highe Score'] = fl['Highe Score'].str.replace('*','')

# %%
def rep(x, a, b, c):
    if c == True:
        pass
    return x.replace(a,b)

fl = fl.apply(rep, args=('--','0', False ))
fl = fl.apply(rep, args=('NaN','0', False ))

# %%
fl.fillna(value=0, inplace=True)
Dat = fl['ODI Debut'].str.replace(',', '-') 
fl['ODI Debut'] = pd.to_datetime(Dat)
fl.groupby('Bowling Style').count()
# Out:
#                                                     Name  Date of birth  Team  \
# Bowling Style
# 0                                                    350            350   350
# Chinaman                                              24             24    24
# Left-arm fast                                          8              8     8
# Left-arm fast-medium                                 104            104   104
# Left-arm fast-medium, Chinaman, Slow left-arm          2              2     2
# Left-arm fast-medium, Slow left-arm, Chinaman          2              2     2
# Left-arm medium                                       44             44    44
# Left-arm medium, Slow left-arm                        20             20    20
# Left-arm medium-fast                                  52             52    52
# Left-arm medium-fast, Slow left-arm                    2              2     2
# Left-arm slow-medium, Left-arm medium                  2              2     2
# Leg-break                                            200            200   200
# Leg-break googly                                     130            130   130
# Leg-break googly, Right-arm medium                     2              2     2
# Leg-break, Off-break                                   2              2     2
# Leg-break, Right-arm medium                            2              2     2
# Off-break                                            714            714   714
# Off-break, Leg-break                                   2              2     2
# Off-break, Right-arm fast-medium                       2              2     2
# Off-break, Right-arm medium                            4              4     4
# Right-arm                                             10             10    10
# Right-arm fast                                       168            168   168
# Right-arm fast-medium                                682            682   682
# Right-arm fast-medium, Leg-break                       2              2     2
# Right-arm fast-medium, Off-break                       4              4     4
# Right-arm fast-medium, Right-arm medium, Off-break     2              2     2
# Right-arm medium                                     756            756   756
# Right-arm medium, Leg-break                           10             10    10
# Right-arm medium, Leg-break googly                     4              4     4
# Right-arm medium, Off-break                           50             50    50
# Right-arm medium, Off-break, Leg-break                 2              2     2
# Right-arm medium-fast                                236            236   236
# Right-arm slow                                         2              2     2
# Right-arm slow, Right-arm fast-medium                  2              2     2
# Right-arm slow-medium                                 14             14    14
# Slow left-arm                                        312            312   312
# Slow left-arm, Left-arm fast-medium                    2              2     2
# Slow left-arm, Left-arm medium                         8              8     8
#
#                                                     Batting Style  ODI Debut  \
# Bowling Style
# 0                                                             350        350
# Chinaman                                                       24         24
# Left-arm fast                                                   8          8
# Left-arm fast-medium                                          104        104
# Left-arm fast-medium, Chinaman, Slow left-arm                   2          2
# Left-arm fast-medium, Slow left-arm, Chinaman                   2          2
# Left-arm medium                                                44         44
# Left-arm medium, Slow left-arm                                 20         20
# Left-arm medium-fast                                           52         52
# Left-arm medium-fast, Slow left-arm                             2          2
# Left-arm slow-medium, Left-arm medium                           2          2
# Leg-break                                                     200        200
# Leg-break googly                                              130        130
# Leg-break googly, Right-arm medium                              2          2
# Leg-break, Off-break                                            2          2
# Leg-break, Right-arm medium                                     2          2
# Off-break                                                     714        714
# Off-break, Leg-break                                            2          2
# Off-break, Right-arm fast-medium                                2          2
# Off-break, Right-arm medium                                     4          4
# Right-arm                                                      10         10
# Right-arm fast                                                168        168
# Right-arm fast-medium                                         682        682
# Right-arm fast-medium, Leg-break                                2          2
# Right-arm fast-medium, Off-break                                4          4
# Right-arm fast-medium, Right-arm medium, Off-break              2          2
# Right-arm medium                                              756        756
# Right-arm medium, Leg-break                                    10         10
# Right-arm medium, Leg-break googly                              4          4
# Right-arm medium, Off-break                                    50         50
# Right-arm medium, Off-break, Leg-break                          2          2
# Right-arm medium-fast                                         236        236
# Right-arm slow                                                  2          2
# Right-arm slow, Right-arm fast-medium                           2          2
# Right-arm slow-medium                                          14         14
# Slow left-arm                                                 312        312
# Slow left-arm, Left-arm fast-medium                             2          2
# Slow left-arm, Left-arm medium                                  8          8
#
#                                                     Debut Team  \
# Bowling Style
# 0                                                          350
# Chinaman                                                    24
# Left-arm fast                                                8
# Left-arm fast-medium                                       104
# Left-arm fast-medium, Chinaman, Slow left-arm                2
# Left-arm fast-medium, Slow left-arm, Chinaman                2
# Left-arm medium                                             44
# Left-arm medium, Slow left-arm                              20
# Left-arm medium-fast                                        52
# Left-arm medium-fast, Slow left-arm                          2
# Left-arm slow-medium, Left-arm medium                        2
# Leg-break                                                  200
# Leg-break googly                                           130
# Leg-break googly, Right-arm medium                           2
# Leg-break, Off-break                                         2
# Leg-break, Right-arm medium                                  2
# Off-break                                                  714
# Off-break, Leg-break                                         2
# Off-break, Right-arm fast-medium                             2
# Off-break, Right-arm medium                                  4
# Right-arm                                                   10
# Right-arm fast                                             168
# Right-arm fast-medium                                      682
# Right-arm fast-medium, Leg-break                             2
# Right-arm fast-medium, Off-break                             4
# Right-arm fast-medium, Right-arm medium, Off-break           2
# Right-arm medium                                           756
# Right-arm medium, Leg-break                                 10
# Right-arm medium, Leg-break googly                           4
# Right-arm medium, Off-break                                 50
# Right-arm medium, Off-break, Leg-break                       2
# Right-arm medium-fast                                      236
# Right-arm slow                                               2
# Right-arm slow, Right-arm fast-medium                        2
# Right-arm slow-medium                                       14
# Slow left-arm                                              312
# Slow left-arm, Left-arm fast-medium                          2
# Slow left-arm, Left-arm medium                               8
#
#                                                     Matches played  Innings  \
# Bowling Style
# 0                                                              350      350
# Chinaman                                                        24       24
# Left-arm fast                                                    8        8
# Left-arm fast-medium                                           104      104
# Left-arm fast-medium, Chinaman, Slow left-arm                    2        2
# Left-arm fast-medium, Slow left-arm, Chinaman                    2        2
# Left-arm medium                                                 44       44
# Left-arm medium, Slow left-arm                                  20       20
# Left-arm medium-fast                                            52       52
# Left-arm medium-fast, Slow left-arm                              2        2
# Left-arm slow-medium, Left-arm medium                            2        2
# Leg-break                                                      200      200
# Leg-break googly                                               130      130
# Leg-break googly, Right-arm medium                               2        2
# Leg-break, Off-break                                             2        2
# Leg-break, Right-arm medium                                      2        2
# Off-break                                                      714      714
# Off-break, Leg-break                                             2        2
# Off-break, Right-arm fast-medium                                 2        2
# Off-break, Right-arm medium                                      4        4
# Right-arm                                                       10       10
# Right-arm fast                                                 168      168
# Right-arm fast-medium                                          682      682
# Right-arm fast-medium, Leg-break                                 2        2
# Right-arm fast-medium, Off-break                                 4        4
# Right-arm fast-medium, Right-arm medium, Off-break               2        2
# Right-arm medium                                               756      756
# Right-arm medium, Leg-break                                     10       10
# Right-arm medium, Leg-break googly                               4        4
# Right-arm medium, Off-break                                     50       50
# Right-arm medium, Off-break, Leg-break                           2        2
# Right-arm medium-fast                                          236      236
# Right-arm slow                                                   2        2
# Right-arm slow, Right-arm fast-medium                            2        2
# Right-arm slow-medium                                           14       14
# Slow left-arm                                                  312      312
# Slow left-arm, Left-arm fast-medium                              2        2
# Slow left-arm, Left-arm medium                                   8        8
#
#                                                     Total Run  Not Out  \
# Bowling Style
# 0                                                         350      350
# Chinaman                                                   24       24
# Left-arm fast                                               8        8
# Left-arm fast-medium                                      104      104
# Left-arm fast-medium, Chinaman, Slow left-arm               2        2
# Left-arm fast-medium, Slow left-arm, Chinaman               2        2
# Left-arm medium                                            44       44
# Left-arm medium, Slow left-arm                             20       20
# Left-arm medium-fast                                       52       52
# Left-arm medium-fast, Slow left-arm                         2        2
# Left-arm slow-medium, Left-arm medium                       2        2
# Leg-break                                                 200      200
# Leg-break googly                                          130      130
# Leg-break googly, Right-arm medium                          2        2
# Leg-break, Off-break                                        2        2
# Leg-break, Right-arm medium                                 2        2
# Off-break                                                 714      714
# Off-break, Leg-break                                        2        2
# Off-break, Right-arm fast-medium                            2        2
# Off-break, Right-arm medium                                 4        4
# Right-arm                                                  10       10
# Right-arm fast                                            168      168
# Right-arm fast-medium                                     682      682
# Right-arm fast-medium, Leg-break                            2        2
# Right-arm fast-medium, Off-break                            4        4
# Right-arm fast-medium, Right-arm medium, Off-break          2        2
# Right-arm medium                                          756      756
# Right-arm medium, Leg-break                                10       10
# Right-arm medium, Leg-break googly                          4        4
# Right-arm medium, Off-break                                50       50
# Right-arm medium, Off-break, Leg-break                      2        2
# Right-arm medium-fast                                     236      236
# Right-arm slow                                              2        2
# Right-arm slow, Right-arm fast-medium                       2        2
# Right-arm slow-medium                                      14       14
# Slow left-arm                                             312      312
# Slow left-arm, Left-arm fast-medium                         2        2
# Slow left-arm, Left-arm medium                              8        8
#
#                                                     Highe Score  Batting Avg  \
# Bowling Style
# 0                                                           350          350
# Chinaman                                                     24           24
# Left-arm fast                                                 8            8
# Left-arm fast-medium                                        104          104
# Left-arm fast-medium, Chinaman, Slow left-arm                 2            2
# Left-arm fast-medium, Slow left-arm, Chinaman                 2            2
# Left-arm medium                                              44           44
# Left-arm medium, Slow left-arm                               20           20
# Left-arm medium-fast                                         52           52
# Left-arm medium-fast, Slow left-arm                           2            2
# Left-arm slow-medium, Left-arm medium                         2            2
# Leg-break                                                   200          200
# Leg-break googly                                            130          130
# Leg-break googly, Right-arm medium                            2            2
# Leg-break, Off-break                                          2            2
# Leg-break, Right-arm medium                                   2            2
# Off-break                                                   714          714
# Off-break, Leg-break                                          2            2
# Off-break, Right-arm fast-medium                              2            2
# Off-break, Right-arm medium                                   4            4
# Right-arm                                                    10           10
# Right-arm fast                                              168          168
# Right-arm fast-medium                                       682          682
# Right-arm fast-medium, Leg-break                              2            2
# Right-arm fast-medium, Off-break                              4            4
# Right-arm fast-medium, Right-arm medium, Off-break            2            2
# Right-arm medium                                            756          756
# Right-arm medium, Leg-break                                  10           10
# Right-arm medium, Leg-break googly                            4            4
# Right-arm medium, Off-break                                  50           50
# Right-arm medium, Off-break, Leg-break                        2            2
# Right-arm medium-fast                                       236          236
# Right-arm slow                                                2            2
# Right-arm slow, Right-arm fast-medium                         2            2
# Right-arm slow-medium                                        14           14
# Slow left-arm                                               312          312
# Slow left-arm, Left-arm fast-medium                           2            2
# Slow left-arm, Left-arm medium                                8            8
#
#                                                     Balls faced  Stick rate  \
# Bowling Style
# 0                                                           350         350
# Chinaman                                                     24          24
# Left-arm fast                                                 8           8
# Left-arm fast-medium                                        104         104
# Left-arm fast-medium, Chinaman, Slow left-arm                 2           2
# Left-arm fast-medium, Slow left-arm, Chinaman                 2           2
# Left-arm medium                                              44          44
# Left-arm medium, Slow left-arm                               20          20
# Left-arm medium-fast                                         52          52
# Left-arm medium-fast, Slow left-arm                           2           2
# Left-arm slow-medium, Left-arm medium                         2           2
# Leg-break                                                   200         200
# Leg-break googly                                            130         130
# Leg-break googly, Right-arm medium                            2           2
# Leg-break, Off-break                                          2           2
# Leg-break, Right-arm medium                                   2           2
# Off-break                                                   714         714
# Off-break, Leg-break                                          2           2
# Off-break, Right-arm fast-medium                              2           2
# Off-break, Right-arm medium                                   4           4
# Right-arm                                                    10          10
# Right-arm fast                                              168         168
# Right-arm fast-medium                                       682         682
# Right-arm fast-medium, Leg-break                              2           2
# Right-arm fast-medium, Off-break                              4           4
# Right-arm fast-medium, Right-arm medium, Off-break            2           2
# Right-arm medium                                            756         756
# Right-arm medium, Leg-break                                  10          10
# Right-arm medium, Leg-break googly                            4           4
# Right-arm medium, Off-break                                  50          50
# Right-arm medium, Off-break, Leg-break                        2           2
# Right-arm medium-fast                                       236         236
# Right-arm slow                                                2           2
# Right-arm slow, Right-arm fast-medium                         2           2
# Right-arm slow-medium                                        14          14
# Slow left-arm                                               312         312
# Slow left-arm, Left-arm fast-medium                           2           2
# Slow left-arm, Left-arm medium                                8           8
#
#                                                     100s  50s   4s   6s  \
# Bowling Style
# 0                                                    350  350  350  350
# Chinaman                                              24   24   24   24
# Left-arm fast                                          8    8    8    8
# Left-arm fast-medium                                 104  104  104  104
# Left-arm fast-medium, Chinaman, Slow left-arm          2    2    2    2
# Left-arm fast-medium, Slow left-arm, Chinaman          2    2    2    2
# Left-arm medium                                       44   44   44   44
# Left-arm medium, Slow left-arm                        20   20   20   20
# Left-arm medium-fast                                  52   52   52   52
# Left-arm medium-fast, Slow left-arm                    2    2    2    2
# Left-arm slow-medium, Left-arm medium                  2    2    2    2
# Leg-break                                            200  200  200  200
# Leg-break googly                                     130  130  130  130
# Leg-break googly, Right-arm medium                     2    2    2    2
# Leg-break, Off-break                                   2    2    2    2
# Leg-break, Right-arm medium                            2    2    2    2
# Off-break                                            714  714  714  714
# Off-break, Leg-break                                   2    2    2    2
# Off-break, Right-arm fast-medium                       2    2    2    2
# Off-break, Right-arm medium                            4    4    4    4
# Right-arm                                             10   10   10   10
# Right-arm fast                                       168  168  168  168
# Right-arm fast-medium                                682  682  682  682
# Right-arm fast-medium, Leg-break                       2    2    2    2
# Right-arm fast-medium, Off-break                       4    4    4    4
# Right-arm fast-medium, Right-arm medium, Off-break     2    2    2    2
# Right-arm medium                                     756  756  756  756
# Right-arm medium, Leg-break                           10   10   10   10
# Right-arm medium, Leg-break googly                     4    4    4    4
# Right-arm medium, Off-break                           50   50   50   50
# Right-arm medium, Off-break, Leg-break                 2    2    2    2
# Right-arm medium-fast                                236  236  236  236
# Right-arm slow                                         2    2    2    2
# Right-arm slow, Right-arm fast-medium                  2    2    2    2
# Right-arm slow-medium                                 14   14   14   14
# Slow left-arm                                        312  312  312  312
# Slow left-arm, Left-arm fast-medium                    2    2    2    2
# Slow left-arm, Left-arm medium                         8    8    8    8
#
#                                                     Caught  Stumped  Balls  \
# Bowling Style
# 0                                                      350      350    350
# Chinaman                                                24       24     24
# Left-arm fast                                            8        8      8
# Left-arm fast-medium                                   104      104    104
# Left-arm fast-medium, Chinaman, Slow left-arm            2        2      2
# Left-arm fast-medium, Slow left-arm, Chinaman            2        2      2
# Left-arm medium                                         44       44     44
# Left-arm medium, Slow left-arm                          20       20     20
# Left-arm medium-fast                                    52       52     52
# Left-arm medium-fast, Slow left-arm                      2        2      2
# Left-arm slow-medium, Left-arm medium                    2        2      2
# Leg-break                                              200      200    200
# Leg-break googly                                       130      130    130
# Leg-break googly, Right-arm medium                       2        2      2
# Leg-break, Off-break                                     2        2      2
# Leg-break, Right-arm medium                              2        2      2
# Off-break                                              714      714    714
# Off-break, Leg-break                                     2        2      2
# Off-break, Right-arm fast-medium                         2        2      2
# Off-break, Right-arm medium                              4        4      4
# Right-arm                                               10       10     10
# Right-arm fast                                         168      168    168
# Right-arm fast-medium                                  682      682    682
# Right-arm fast-medium, Leg-break                         2        2      2
# Right-arm fast-medium, Off-break                         4        4      4
# Right-arm fast-medium, Right-arm medium, Off-break       2        2      2
# Right-arm medium                                       756      756    756
# Right-arm medium, Leg-break                             10       10     10
# Right-arm medium, Leg-break googly                       4        4      4
# Right-arm medium, Off-break                             50       50     50
# Right-arm medium, Off-break, Leg-break                   2        2      2
# Right-arm medium-fast                                  236      236    236
# Right-arm slow                                           2        2      2
# Right-arm slow, Right-arm fast-medium                    2        2      2
# Right-arm slow-medium                                   14       14     14
# Slow left-arm                                          312      312    312
# Slow left-arm, Left-arm fast-medium                      2        2      2
# Slow left-arm, Left-arm medium                           8        8      8
#
#                                                     Runs  Wickets  \
# Bowling Style
# 0                                                    350      350
# Chinaman                                              24       24
# Left-arm fast                                          8        8
# Left-arm fast-medium                                 104      104
# Left-arm fast-medium, Chinaman, Slow left-arm          2        2
# Left-arm fast-medium, Slow left-arm, Chinaman          2        2
# Left-arm medium                                       44       44
# Left-arm medium, Slow left-arm                        20       20
# Left-arm medium-fast                                  52       52
# Left-arm medium-fast, Slow left-arm                    2        2
# Left-arm slow-medium, Left-arm medium                  2        2
# Leg-break                                            200      200
# Leg-break googly                                     130      130
# Leg-break googly, Right-arm medium                     2        2
# Leg-break, Off-break                                   2        2
# Leg-break, Right-arm medium                            2        2
# Off-break                                            714      714
# Off-break, Leg-break                                   2        2
# Off-break, Right-arm fast-medium                       2        2
# Off-break, Right-arm medium                            4        4
# Right-arm                                             10       10
# Right-arm fast                                       168      168
# Right-arm fast-medium                                682      682
# Right-arm fast-medium, Leg-break                       2        2
# Right-arm fast-medium, Off-break                       4        4
# Right-arm fast-medium, Right-arm medium, Off-break     2        2
# Right-arm medium                                     756      756
# Right-arm medium, Leg-break                           10       10
# Right-arm medium, Leg-break googly                     4        4
# Right-arm medium, Off-break                           50       50
# Right-arm medium, Off-break, Leg-break                 2        2
# Right-arm medium-fast                                236      236
# Right-arm slow                                         2        2
# Right-arm slow, Right-arm fast-medium                  2        2
# Right-arm slow-medium                                 14       14
# Slow left-arm                                        312      312
# Slow left-arm, Left-arm fast-medium                    2        2
# Slow left-arm, Left-arm medium                         8        8
#
#                                                     Bowling Avg  Economy  \
# Bowling Style
# 0                                                           350      350
# Chinaman                                                     24       24
# Left-arm fast                                                 8        8
# Left-arm fast-medium                                        104      104
# Left-arm fast-medium, Chinaman, Slow left-arm                 2        2
# Left-arm fast-medium, Slow left-arm, Chinaman                 2        2
# Left-arm medium                                              44       44
# Left-arm medium, Slow left-arm                               20       20
# Left-arm medium-fast                                         52       52
# Left-arm medium-fast, Slow left-arm                           2        2
# Left-arm slow-medium, Left-arm medium                         2        2
# Leg-break                                                   200      200
# Leg-break googly                                            130      130
# Leg-break googly, Right-arm medium                            2        2
# Leg-break, Off-break                                          2        2
# Leg-break, Right-arm medium                                   2        2
# Off-break                                                   714      714
# Off-break, Leg-break                                          2        2
# Off-break, Right-arm fast-medium                              2        2
# Off-break, Right-arm medium                                   4        4
# Right-arm                                                    10       10
# Right-arm fast                                              168      168
# Right-arm fast-medium                                       682      682
# Right-arm fast-medium, Leg-break                              2        2
# Right-arm fast-medium, Off-break                              4        4
# Right-arm fast-medium, Right-arm medium, Off-break            2        2
# Right-arm medium                                            756      756
# Right-arm medium, Leg-break                                  10       10
# Right-arm medium, Leg-break googly                            4        4
# Right-arm medium, Off-break                                  50       50
# Right-arm medium, Off-break, Leg-break                        2        2
# Right-arm medium-fast                                       236      236
# Right-arm slow                                                2        2
# Right-arm slow, Right-arm fast-medium                         2        2
# Right-arm slow-medium                                        14       14
# Slow left-arm                                               312      312
# Slow left-arm, Left-arm fast-medium                           2        2
# Slow left-arm, Left-arm medium                                8        8
#
#                                                     Stick rate.1  5WI  10WM  \
# Bowling Style
# 0                                                            350  350   350
# Chinaman                                                      24   24    24
# Left-arm fast                                                  8    8     8
# Left-arm fast-medium                                         104  104   104
# Left-arm fast-medium, Chinaman, Slow left-arm                  2    2     2
# Left-arm fast-medium, Slow left-arm, Chinaman                  2    2     2
# Left-arm medium                                               44   44    44
# Left-arm medium, Slow left-arm                                20   20    20
# Left-arm medium-fast                                          52   52    52
# Left-arm medium-fast, Slow left-arm                            2    2     2
# Left-arm slow-medium, Left-arm medium                          2    2     2
# Leg-break                                                    200  200   200
# Leg-break googly                                             130  130   130
# Leg-break googly, Right-arm medium                             2    2     2
# Leg-break, Off-break                                           2    2     2
# Leg-break, Right-arm medium                                    2    2     2
# Off-break                                                    714  714   714
# Off-break, Leg-break                                           2    2     2
# Off-break, Right-arm fast-medium                               2    2     2
# Off-break, Right-arm medium                                    4    4     4
# Right-arm                                                     10   10    10
# Right-arm fast                                               168  168   168
# Right-arm fast-medium                                        682  682   682
# Right-arm fast-medium, Leg-break                               2    2     2
# Right-arm fast-medium, Off-break                               4    4     4
# Right-arm fast-medium, Right-arm medium, Off-break             2    2     2
# Right-arm medium                                             756  756   756
# Right-arm medium, Leg-break                                   10   10    10
# Right-arm medium, Leg-break googly                             4    4     4
# Right-arm medium, Off-break                                   50   50    50
# Right-arm medium, Off-break, Leg-break                         2    2     2
# Right-arm medium-fast                                        236  236   236
# Right-arm slow                                                 2    2     2
# Right-arm slow, Right-arm fast-medium                          2    2     2
# Right-arm slow-medium                                         14   14    14
# Slow left-arm                                                312  312   312
# Slow left-arm, Left-arm fast-medium                            2    2     2
# Slow left-arm, Left-arm medium                                 8    8     8
#
#                                                     BBI  BBM
# Bowling Style
# 0                                                   350  350
# Chinaman                                             24   24
# Left-arm fast                                         8    8
# Left-arm fast-medium                                104  104
# Left-arm fast-medium, Chinaman, Slow left-arm         2    2
# Left-arm fast-medium, Slow left-arm, Chinaman         2    2
# Left-arm medium                                      44   44
# Left-arm medium, Slow left-arm                       20   20
# Left-arm medium-fast                                 52   52
# Left-arm medium-fast, Slow left-arm                   2    2
# Left-arm slow-medium, Left-arm medium                 2    2
# Leg-break                                           200  200
# Leg-break googly                                    130  130
# Leg-break googly, Right-arm medium                    2    2
# Leg-break, Off-break                                  2    2
# Leg-break, Right-arm medium                           2    2
# Off-break                                           714  714
# Off-break, Leg-break                                  2    2
# Off-break, Right-arm fast-medium                      2    2
# Off-break, Right-arm medium                           4    4
# Right-arm                                            10   10
# Right-arm fast                                      168  168
# Right-arm fast-medium                               682  682
# Right-arm fast-medium, Leg-break                      2    2
# Right-arm fast-medium, Off-break                      4    4
# Right-arm fast-medium, Right-arm medium, Off-break    2    2
# Right-arm medium                                    756  756
# Right-arm medium, Leg-break                          10   10
# Right-arm medium, Leg-break googly                    4    4
# Right-arm medium, Off-break                          50   50
# Right-arm medium, Off-break, Leg-break                2    2
# Right-arm medium-fast                               236  236
# Right-arm slow                                        2    2
# Right-arm slow, Right-arm fast-medium                 2    2
# Right-arm slow-medium                                14   14
# Slow left-arm                                       312  312
# Slow left-arm, Left-arm fast-medium                   2    2
# Slow left-arm, Left-arm medium                        8    8

# %%
cols = fl.columns[7:-2]

fl[cols] = fl[cols].apply(pd.to_numeric)

#fl[fl['Bowling Style'] == 0]
fl['Bowling Style'] = fl['Bowling Style'].map(lambda s: str(s).replace('0', 'Not-Bowled')) 
fl['Batting Style'] = fl['Batting Style'].map(lambda s: str(s).replace('0', 'Right-hand bat')) 


fl.to_csv('all_odi_players.csv', index = False)

# %%
ODI = pd.read_csv('all_odi_players.csv')
#ODI.groupby('Team').count()
ODI.shape
# Out:
# (3934, 31)

# %%
ODI.groupby('Bowling Style')['Balls'].sum()
# Out:
# Bowling Style
# Chinaman                                                20290
# Left-arm fast                                           58850
# Left-arm fast-medium                                   187382
# Left-arm fast-medium, Chinaman, Slow left-arm            1524
# Left-arm fast-medium, Slow left-arm, Chinaman             126
# Left-arm medium                                         11852
# Left-arm medium, Slow left-arm                           3994
# Left-arm medium-fast                                    81086
# Left-arm medium-fast, Slow left-arm                       540
# Left-arm slow-medium, Left-arm medium                    2532
# Leg-break                                               48984
# Leg-break googly                                       194084
# Leg-break googly, Right-arm medium                       3604
# Leg-break, Off-break                                     1394
# Leg-break, Right-arm medium                              6148
# Not-Bowled                                                312
# Off-break                                              590088
# Off-break, Leg-break                                     1076
# Off-break, Right-arm fast-medium                         4728
# Off-break, Right-arm medium                               978
# Right-arm                                                   0
# Right-arm fast                                         502050
# Right-arm fast-medium                                 1095520
# Right-arm fast-medium, Leg-break                         7150
# Right-arm fast-medium, Off-break                         7248
# Right-arm fast-medium, Right-arm medium, Off-break        396
# Right-arm medium                                       416024
# Right-arm medium, Leg-break                              8082
# Right-arm medium, Leg-break googly                       1614
# Right-arm medium, Off-break                             68974
# Right-arm medium, Off-break, Leg-break                  16108
# Right-arm medium-fast                                  234534
# Right-arm slow                                           8308
# Right-arm slow, Right-arm fast-medium                    3192
# Right-arm slow-medium                                     130
# Slow left-arm                                          367960
# Slow left-arm, Left-arm fast-medium                       894
# Slow left-arm, Left-arm medium                          13348
# Name: Balls, dtype: int64
