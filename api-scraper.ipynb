# %%
from bs4 import BeautifulSoup as bs
import requests
import os
import pandas as pd
import glob
import json

agent = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}

h = 0

dic = []
col = ['category', 'type', 'difficulty', 'question', 'correct_answer', 'in1', 'in2', 'in3' ] 
while h <= 75:
    url = requests.get('https://opentdb.com/api.php?amount=50', headers=agent).text
    
    scr = bs(url, 'lxml')
    
    api = scr.select_one('p').text
    
    api2 = api.replace('{', 'r~ ').replace('},', '').replace(']}]}', ']}').replace('":"',':').replace('":',':')#.replace('"','')
    
    api2 = api2.split('r~ ')
    
    
    di = {'category':[], 'type':[] } 
    k = 0
    for i in api2:
        
        if k > 1:
            i = i.replace('{','').replace('}','').replace('[', '').replace(']', '')#.replace('"','')
            i = i.split('","')
           # print(i) 
            if i in dic:
                pass
            else:
                dic.append(i)
        k += 1
    
    #dict['results'].append(di)
    h += 1
    
df = pd.DataFrame(dic, columns=col)
df

#li = pd.concat(df, ignore_index=True)


#df.to_json('api-quiz.json', orient = 'records')
# Out:
# ['"category:General Knowledge', 'type:multiple', 'difficulty:hard', 'question:Before the 19th Century, the "Living Room" was originally called the...', 'correct_answer:Parlor', 'incorrect_answers:"Open Room', 'Sitting Room', 'Loft"']
# ['"category:Entertainment: Film', 'type:multiple', 'difficulty:medium', 'question:What is the name of the Artificial Intelligence system in the 1983 film, "WarGames"?', 'correct_answer:War Operation Plan Response', 'incorrect_answers:"Self Evolving Thought Helix', 'Master Control Program', 'West Campus Analog Computer"']
# ['"category:Politics', 'type:multiple', 'difficulty:medium', 'question:The 2014 movie "The Raid 2: Berandal" was mainly filmed in which Asian country?', 'correct_answer:Indonesia', 'incorrect_answers:"Thailand', 'Brunei', 'Malaysia"']
# ['"category:Entertainment: Video Games', 'type:multiple', 'difficulty:medium', 'question:Which puzzle game was designed by a Russian programmer, featuring Russian buildings and music?', 'correct_answer:Tetris', 'incorrect_answers:"Jenga', 'Boulder Dash', 'Puzzled"']
# ['"category:Geography', 'type:multiple', 'difficulty:easy', "question:How many stars are featured on New Zealand's flag?", 'correct_answer:4', 'incorrect_answers:"5', '2', '0"']
# ['"category:Entertainment: Music', 'type:multiple', 'difficulty:medium', 'question:How many members are in the Japanese rock band SCANDAL?', 'correct_answer:4', 'incorrect_answers:"5', '2', '18"']
# ['"category:Entertainment: Video Games', 'type:multiple', 'difficulty:hard', 'question:Which of the following games in the The Legend of Zelda franchise was released in Japan before North America?', 'correct_answer:The Legend of Zelda: The Minish Cap', 'incorrect_answers:"The Legend of Zelda: Twilight Princess', 'The Legend of Zelda: Spirit Tracks', 'The Legend of Zelda: Four Swords"']
# ['"category:Entertainment: Japanese Anime & Manga', 'type:multiple', 'difficulty:medium', 'question:Who voices "Shou Suzuki" in the English dub of "Mob Psycho 100"?', 'correct_answer:Casey Mongillo', 'incorrect_answers:"Ben Diskin', 'Chris Niosi', 'David Naughton"']
# ['"category:History', 'type:multiple', 'difficulty:hard', "question:Which of the following was not one of Joseph Stalin's ten blows during World War II?", 'correct_answer:Vistula-Oder Offensive', 'incorrect_answers:"Crimean Offensive', 'Leningrad-Novgorod Offensive', 'Operation Bagration"']
# ['"category:Entertainment: Video Games', 'type:multiple', 'difficulty:medium', 'question:What former MOBA, created by Waystone Games and published by EA, was shut down in 2014?', 'correct_answer:Dawngate', 'incorrect_answers:"Strife', 'League of Legends', 'Heroes of Newerth"']
# ['"category:Entertainment: Music', 'type:multiple', 'difficulty:medium', 'question:What was the title of ABBA`s first UK hit single?', 'correct_answer:Waterloo', 'incorrect_answers:"Mamma Mia', 'Fernando', 'Dancing Queen"']
# ['"category:Entertainment: Music', 'type:multiple', 'difficulty:easy', 'question:Ringo Starr of The Beatles mainly played what instrument?', 'correct_answer:Drums', 'incorrect_answers:"Bass', 'Guitar', 'Piano"']
# ['"category:Mythology', 'type:multiple', 'difficulty:medium', 'question:The Hippogriff, not to be confused with the Griffon, is a magical creature with the front half of an eagle, and the back half of what?', 'correct_answer:A Horse', 'incorrect_answers:"A Dragon', 'A Tiger', 'A Lion"']
# ['"category:Entertainment: Music', 'type:multiple', 'difficulty:hard', 'question:Who was the original drummer for The Beatles?', 'correct_answer:Tommy Moore', 'incorrect_answers:"Ringo Starr', 'Stuart Sutcliffe', 'Pete Best"']
# ['"category:Entertainment: Video Games', 'type:multiple', 'difficulty:medium', 'question:How many Star Spirits do you rescue in the Nintendo 64 video game "Paper Mario"?', 'correct_answer:7', 'incorrect_answers:"5', '10', '12"']
# ['"category:General Knowledge', 'type:multiple', 'difficulty:medium', 'question:What is a "dakimakura"?', 'correct_answer:A body pillow', 'incorrect_answers:"A Chinese meal, essentially composed of fish', 'A yoga posture', 'A word used to describe two people who truly love each other"']
# ['"category:Entertainment: Video Games', 'type:multiple', 'difficulty:hard', 'question:Which of these weapon classes DO NOT appear in the first Monster Hunter game?', 'correct_answer:Bow ', 'incorrect_answers:"Hammer', 'Heavy Bowgun', 'Light Bowgun"']
# ['"category:Politics', 'type:boolean', 'difficulty:medium', 'question:Helen Clark was the 37th Prime Minister of Australia.', 'correct_answer:False', 'incorrect_answers:"True"']
# ['"category:Entertainment: Cartoon & Animations', 'type:multiple', 'difficulty:medium', 'question:What was the number on Gerald\'s shirt in "Hey Arnold!"?', 'correct_answer:33', 'incorrect_answers:"88', '38', '83"']
# ['"category:Entertainment: Cartoon & Animations', 'type:boolean', 'difficulty:medium', "question:Snagglepuss was part of the Yogi Yahooies in the 1977 show Scooby's All-Star Laff-a-Lympics.", 'correct_answer:False', 'incorrect_answers:"True"']
#                                            category           type  \
# 0                       "category:General Knowledge  type:multiple
# 1                     "category:Entertainment: Film  type:multiple
# 2                                "category:Politics  type:multiple
# 3              "category:Entertainment: Video Games  type:multiple
# 4                               "category:Geography  type:multiple
# 5                    "category:Entertainment: Music  type:multiple
# 6              "category:Entertainment: Video Games  type:multiple
# 7   "category:Entertainment: Japanese Anime & Manga  type:multiple
# 8                                 "category:History  type:multiple
# 9              "category:Entertainment: Video Games  type:multiple
# 10                   "category:Entertainment: Music  type:multiple
# 11                   "category:Entertainment: Music  type:multiple
# 12                              "category:Mythology  type:multiple
# 13                   "category:Entertainment: Music  type:multiple
# 14             "category:Entertainment: Video Games  type:multiple
# 15                      "category:General Knowledge  type:multiple
# 16             "category:Entertainment: Video Games  type:multiple
# 17                               "category:Politics   type:boolean
# 18    "category:Entertainment: Cartoon & Animations  type:multiple
# 19    "category:Entertainment: Cartoon & Animations   type:boolean
#
#            difficulty                                           question  \
# 0     difficulty:hard  question:Before the 19th Century, the "Living ...
# 1   difficulty:medium  question:What is the name of the Artificial In...
# 2   difficulty:medium  question:The 2014 movie "The Raid 2: Berandal"...
# 3   difficulty:medium  question:Which puzzle game was designed by a R...
# 4     difficulty:easy  question:How many stars are featured on New Ze...
# 5   difficulty:medium  question:How many members are in the Japanese ...
# 6     difficulty:hard  question:Which of the following games in the T...
# 7   difficulty:medium  question:Who voices "Shou Suzuki" in the Engli...
# 8     difficulty:hard  question:Which of the following was not one of...
# 9   difficulty:medium  question:What former MOBA, created by Waystone...
# 10  difficulty:medium  question:What was the title of ABBA`s first UK...
# 11    difficulty:easy  question:Ringo Starr of The Beatles mainly pla...
# 12  difficulty:medium  question:The Hippogriff, not to be confused wi...
# 13    difficulty:hard  question:Who was the original drummer for The ...
# 14  difficulty:medium  question:How many Star Spirits do you rescue i...
# 15  difficulty:medium                   question:What is a "dakimakura"?
# 16    difficulty:hard  question:Which of these weapon classes DO NOT ...
# 17  difficulty:medium  question:Helen Clark was the 37th Prime Minist...
# 18  difficulty:medium  question:What was the number on Gerald's shirt...
# 19  difficulty:medium  question:Snagglepuss was part of the Yogi Yaho...
#
#                                        correct_answer  \
# 0                               correct_answer:Parlor
# 1          correct_answer:War Operation Plan Response
# 2                            correct_answer:Indonesia
# 3                               correct_answer:Tetris
# 4                                    correct_answer:4
# 5                                    correct_answer:4
# 6   correct_answer:The Legend of Zelda: The Minish...
# 7                       correct_answer:Casey Mongillo
# 8               correct_answer:Vistula-Oder Offensive
# 9                             correct_answer:Dawngate
# 10                            correct_answer:Waterloo
# 11                               correct_answer:Drums
# 12                             correct_answer:A Horse
# 13                         correct_answer:Tommy Moore
# 14                                   correct_answer:7
# 15                       correct_answer:A body pillow
# 16                                correct_answer:Bow
# 17                               correct_answer:False
# 18                                  correct_answer:33
# 19                               correct_answer:False
#
#                                                   in1  \
# 0                        incorrect_answers:"Open Room
# 1      incorrect_answers:"Self Evolving Thought Helix
# 2                         incorrect_answers:"Thailand
# 3                            incorrect_answers:"Jenga
# 4                                incorrect_answers:"5
# 5                                incorrect_answers:"5
# 6   incorrect_answers:"The Legend of Zelda: Twilig...
# 7                       incorrect_answers:"Ben Diskin
# 8                incorrect_answers:"Crimean Offensive
# 9                           incorrect_answers:"Strife
# 10                       incorrect_answers:"Mamma Mia
# 11                            incorrect_answers:"Bass
# 12                        incorrect_answers:"A Dragon
# 13                     incorrect_answers:"Ringo Starr
# 14                               incorrect_answers:"5
# 15  incorrect_answers:"A Chinese meal, essentially...
# 16                          incorrect_answers:"Hammer
# 17                           incorrect_answers:"True"
# 18                              incorrect_answers:"88
# 19                           incorrect_answers:"True"
#
#                                    in2  \
# 0                         Sitting Room
# 1               Master Control Program
# 2                               Brunei
# 3                         Boulder Dash
# 4                                    2
# 5                                    2
# 6   The Legend of Zelda: Spirit Tracks
# 7                          Chris Niosi
# 8         Leningrad-Novgorod Offensive
# 9                    League of Legends
# 10                            Fernando
# 11                              Guitar
# 12                             A Tiger
# 13                    Stuart Sutcliffe
# 14                                  10
# 15                      A yoga posture
# 16                        Heavy Bowgun
# 17                                None
# 18                                  38
# 19                                None
#
#                                                   in3
# 0                                               Loft"
# 1                        West Campus Analog Computer"
# 2                                           Malaysia"
# 3                                            Puzzled"
# 4                                                  0"
# 5                                                 18"
# 6                   The Legend of Zelda: Four Swords"
# 7                                     David Naughton"
# 8                                Operation Bagration"
# 9                                  Heroes of Newerth"
# 10                                     Dancing Queen"
# 11                                             Piano"
# 12                                            A Lion"
# 13                                         Pete Best"
# 14                                                12"
# 15  A word used to describe two people who truly l...
# 16                                      Light Bowgun"
# 17                                               None
# 18                                                83"
# 19                                               None

# %%
#df = df.replace('"','')

df['category'] = df['category'].str.replace('"', '')
df['in1'] = df['in1'].str.replace('"','') 
df['in3'] = df['in3'].str.replace('"', '')

# %%
deb = df['category'].apply(lambda x: x.split(':'))
deb2 = df['type'].apply(lambda x: x.split(':'))
deb3 = df['difficulty'].apply(lambda x: x.split(':'))
deb4 = df['question'].apply(lambda x: x.split(':'))
deb5 = df['correct_answer'].apply(lambda x: x.split(':'))
deb6 = df['in1'].apply(lambda x: x.split(':'))

def ch(x):
    if len(x) == 3:
        return f'{x[1]}:{x[2]}'
    else :
        return x[1]

df['category'] = deb.apply(ch)
df['type'] = deb2.apply(ch) 
df['difficulty'] = deb3.apply(ch) 
df['question'] = deb4.apply(ch) 
df['correct_answer'] = deb5.apply(ch) 
df['in1'] = deb6.apply(ch)

# %%
df['incorrect_answers'] = df[['in1', 'in2', 'in3']].values.tolist()
df['incorrect_answers'] = df['incorrect_answers'].apply(lambda x : [i for i in x if i])
# Out:
#                                  category      type difficulty  \
# 0                       General Knowledge  multiple       hard
# 1                     Entertainment: Film  multiple     medium
# 2                                Politics  multiple     medium
# 3              Entertainment: Video Games  multiple     medium
# 4                               Geography  multiple       easy
# 5                    Entertainment: Music  multiple     medium
# 6              Entertainment: Video Games  multiple       hard
# 7   Entertainment: Japanese Anime & Manga  multiple     medium
# 8                                 History  multiple       hard
# 9              Entertainment: Video Games  multiple     medium
# 10                   Entertainment: Music  multiple     medium
# 11                   Entertainment: Music  multiple       easy
# 12                              Mythology  multiple     medium
# 13                   Entertainment: Music  multiple       hard
# 14             Entertainment: Video Games  multiple     medium
# 15                      General Knowledge  multiple     medium
# 16             Entertainment: Video Games  multiple       hard
# 17                               Politics   boolean     medium
# 18    Entertainment: Cartoon & Animations  multiple     medium
# 19    Entertainment: Cartoon & Animations   boolean     medium
#
#                                              question  \
# 0   Before the 19th Century, the "Living Room" was...
# 1   What is the name of the Artificial Intelligenc...
# 2   The 2014 movie "The Raid 2: Berandal" was main...
# 3   Which puzzle game was designed by a Russian pr...
# 4   How many stars are featured on New Zealand's f...
# 5   How many members are in the Japanese rock band...
# 6   Which of the following games in the The Legend...
# 7   Who voices "Shou Suzuki" in the English dub of...
# 8   Which of the following was not one of Joseph S...
# 9   What former MOBA, created by Waystone Games an...
# 10  What was the title of ABBA`s first UK hit single?
# 11  Ringo Starr of The Beatles mainly played what ...
# 12  The Hippogriff, not to be confused with the Gr...
# 13      Who was the original drummer for The Beatles?
# 14  How many Star Spirits do you rescue in the Nin...
# 15                            What is a "dakimakura"?
# 16  Which of these weapon classes DO NOT appear in...
# 17  Helen Clark was the 37th Prime Minister of Aus...
# 18  What was the number on Gerald's shirt in "Hey ...
# 19  Snagglepuss was part of the Yogi Yahooies in t...
#
#                          correct_answer  \
# 0                                Parlor
# 1           War Operation Plan Response
# 2                             Indonesia
# 3                                Tetris
# 4                                     4
# 5                                     4
# 6   The Legend of Zelda: The Minish Cap
# 7                        Casey Mongillo
# 8                Vistula-Oder Offensive
# 9                              Dawngate
# 10                             Waterloo
# 11                                Drums
# 12                              A Horse
# 13                          Tommy Moore
# 14                                    7
# 15                        A body pillow
# 16                                 Bow
# 17                                False
# 18                                   33
# 19                                False
#
#                                              in1  \
# 0                                      Open Room
# 1                    Self Evolving Thought Helix
# 2                                       Thailand
# 3                                          Jenga
# 4                                              5
# 5                                              5
# 6         The Legend of Zelda: Twilight Princess
# 7                                     Ben Diskin
# 8                              Crimean Offensive
# 9                                         Strife
# 10                                     Mamma Mia
# 11                                          Bass
# 12                                      A Dragon
# 13                                   Ringo Starr
# 14                                             5
# 15  A Chinese meal, essentially composed of fish
# 16                                        Hammer
# 17                                          True
# 18                                            88
# 19                                          True
#
#                                    in2  \
# 0                         Sitting Room
# 1               Master Control Program
# 2                               Brunei
# 3                         Boulder Dash
# 4                                    2
# 5                                    2
# 6   The Legend of Zelda: Spirit Tracks
# 7                          Chris Niosi
# 8         Leningrad-Novgorod Offensive
# 9                    League of Legends
# 10                            Fernando
# 11                              Guitar
# 12                             A Tiger
# 13                    Stuart Sutcliffe
# 14                                  10
# 15                      A yoga posture
# 16                        Heavy Bowgun
# 17                                None
# 18                                  38
# 19                                None
#
#                                                   in3  \
# 0                                                Loft
# 1                         West Campus Analog Computer
# 2                                            Malaysia
# 3                                             Puzzled
# 4                                                   0
# 5                                                  18
# 6                    The Legend of Zelda: Four Swords
# 7                                      David Naughton
# 8                                 Operation Bagration
# 9                                   Heroes of Newerth
# 10                                      Dancing Queen
# 11                                              Piano
# 12                                             A Lion
# 13                                          Pete Best
# 14                                                 12
# 15  A word used to describe two people who truly l...
# 16                                       Light Bowgun
# 17                                               None
# 18                                                 83
# 19                                               None
#
#                                     incorrect_answers
# 0                     [Open Room, Sitting Room, Loft]
# 1   [Self Evolving Thought Helix, Master Control P...
# 2                        [Thailand, Brunei, Malaysia]
# 3                      [Jenga, Boulder Dash, Puzzled]
# 4                                           [5, 2, 0]
# 5                                          [5, 2, 18]
# 6   [The Legend of Zelda: Twilight Princess, The L...
# 7           [Ben Diskin, Chris Niosi, David Naughton]
# 8   [Crimean Offensive, Leningrad-Novgorod Offensi...
# 9      [Strife, League of Legends, Heroes of Newerth]
# 10               [Mamma Mia, Fernando, Dancing Queen]
# 11                              [Bass, Guitar, Piano]
# 12                        [A Dragon, A Tiger, A Lion]
# 13         [Ringo Starr, Stuart Sutcliffe, Pete Best]
# 14                                        [5, 10, 12]
# 15  [A Chinese meal, essentially composed of fish,...
# 16               [Hammer, Heavy Bowgun, Light Bowgun]
# 17                                             [True]
# 18                                       [88, 38, 83]
# 19                                             [True]

# %%
df.drop(df.iloc[:, 5:8], inplace = True, axis = 1)
df
# Out:
#                                  category      type difficulty  \
# 0                       General Knowledge  multiple       hard
# 1                     Entertainment: Film  multiple     medium
# 2                                Politics  multiple     medium
# 3              Entertainment: Video Games  multiple     medium
# 4                               Geography  multiple       easy
# 5                    Entertainment: Music  multiple     medium
# 6              Entertainment: Video Games  multiple       hard
# 7   Entertainment: Japanese Anime & Manga  multiple     medium
# 8                                 History  multiple       hard
# 9              Entertainment: Video Games  multiple     medium
# 10                   Entertainment: Music  multiple     medium
# 11                   Entertainment: Music  multiple       easy
# 12                              Mythology  multiple     medium
# 13                   Entertainment: Music  multiple       hard
# 14             Entertainment: Video Games  multiple     medium
# 15                      General Knowledge  multiple     medium
# 16             Entertainment: Video Games  multiple       hard
# 17                               Politics   boolean     medium
# 18    Entertainment: Cartoon & Animations  multiple     medium
# 19    Entertainment: Cartoon & Animations   boolean     medium
#
#                                              question  \
# 0   Before the 19th Century, the "Living Room" was...
# 1   What is the name of the Artificial Intelligenc...
# 2   The 2014 movie "The Raid 2: Berandal" was main...
# 3   Which puzzle game was designed by a Russian pr...
# 4   How many stars are featured on New Zealand's f...
# 5   How many members are in the Japanese rock band...
# 6   Which of the following games in the The Legend...
# 7   Who voices "Shou Suzuki" in the English dub of...
# 8   Which of the following was not one of Joseph S...
# 9   What former MOBA, created by Waystone Games an...
# 10  What was the title of ABBA`s first UK hit single?
# 11  Ringo Starr of The Beatles mainly played what ...
# 12  The Hippogriff, not to be confused with the Gr...
# 13      Who was the original drummer for The Beatles?
# 14  How many Star Spirits do you rescue in the Nin...
# 15                            What is a "dakimakura"?
# 16  Which of these weapon classes DO NOT appear in...
# 17  Helen Clark was the 37th Prime Minister of Aus...
# 18  What was the number on Gerald's shirt in "Hey ...
# 19  Snagglepuss was part of the Yogi Yahooies in t...
#
#                          correct_answer  \
# 0                                Parlor
# 1           War Operation Plan Response
# 2                             Indonesia
# 3                                Tetris
# 4                                     4
# 5                                     4
# 6   The Legend of Zelda: The Minish Cap
# 7                        Casey Mongillo
# 8                Vistula-Oder Offensive
# 9                              Dawngate
# 10                             Waterloo
# 11                                Drums
# 12                              A Horse
# 13                          Tommy Moore
# 14                                    7
# 15                        A body pillow
# 16                                 Bow
# 17                                False
# 18                                   33
# 19                                False
#
#                                     incorrect_answers
# 0                     [Open Room, Sitting Room, Loft]
# 1   [Self Evolving Thought Helix, Master Control P...
# 2                        [Thailand, Brunei, Malaysia]
# 3                      [Jenga, Boulder Dash, Puzzled]
# 4                                           [5, 2, 0]
# 5                                          [5, 2, 18]
# 6   [The Legend of Zelda: Twilight Princess, The L...
# 7           [Ben Diskin, Chris Niosi, David Naughton]
# 8   [Crimean Offensive, Leningrad-Novgorod Offensi...
# 9      [Strife, League of Legends, Heroes of Newerth]
# 10               [Mamma Mia, Fernando, Dancing Queen]
# 11                              [Bass, Guitar, Piano]
# 12                        [A Dragon, A Tiger, A Lion]
# 13         [Ringo Starr, Stuart Sutcliffe, Pete Best]
# 14                                        [5, 10, 12]
# 15  [A Chinese meal, essentially composed of fish,...
# 16               [Hammer, Heavy Bowgun, Light Bowgun]
# 17                                             [True]
# 18                                       [88, 38, 83]
# 19                                             [True]

# %%
li2 = {'results' : [df]} 
df2 = pd.DataFrame(li2)

# %%
df2.to_json('api-quiz.json', orient = 'records')

# %%
import pandas as pd

fl3 = pd.read_json('api-quiz3.json') 
fl3
# Out:
#                                    category      type difficulty  \
# 0                         General Knowledge  multiple       easy
# 1                                  Vehicles   boolean       hard
# 2                          Science & Nature  multiple       easy
# 3                                   History  multiple       easy
# 4                         General Knowledge  multiple       easy
# ...                                     ...       ...        ...
# 2365                       Science & Nature   boolean       easy
# 2366                      General Knowledge  multiple       easy
# 2367  Entertainment: Japanese Anime & Manga  multiple       hard
# 2368  Entertainment: Japanese Anime & Manga  multiple       hard
# 2369                   Entertainment: Books  multiple       hard
#
#                                                question  \
# 0     Virgin Trains, Virgin Atlantic and Virgin Raci...
# 1     In 1993 Swedish car manufacturer Saab experime...
# 2         What does the letter 'S' stand for in 'NASA'?
# 3      What was William Frederick Cody better known as?
# 4          What is the first book of the Old Testament?
# ...                                                 ...
# 2365  Celiac Disease is a disease that effects the h...
# 2366  What machine element is located in the center ...
# 2367  In which manga did the "404 Girl" from 4chan o...
# 2368     In the Overlord Anime who was Cocytus made by?
# 2369  Which author co-wrote "The Communist Manifesto...
#
#              correct_answer                                  incorrect_answers
# 0           Richard Branson             [Alan Sugar, Donald Trump, Bill Gates]
# 1                      True                                            [False]
# 2                     Space                           [Science, Society, Star]
# 3              Buffalo Bill     [Billy the Kid, Wild Bill Hickok, Pawnee Bill]
# 4                   Genesis                       [Exodus, Leviticus, Numbers]
# ...                     ...                                                ...
# 2365                  False                                             [True]
# 2366               Bearings                              [Axles, Gears, Belts]
# 2367              Yotsuba&!               [Azumanga Daioh, Lucky Star, Clover]
# 2368  Warrior Takemikazuchi  [Peroroncino, Ulbert Alain Odle, Bukubukuchagama]
# 2369       Friedrich Engels   [Robert Owen, Alexander Kerensky, Paul Lafargue]
#
# [2370 rows x 6 columns]
